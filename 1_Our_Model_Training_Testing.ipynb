# %% [markdown]
# # Train_Our_Model

# %%
from train import *
training()

# %% [markdown]
# # Testing Our Model

# %%
from test_model import *
model_testing()
# Out:
# ...
# 16/16 [==============================] - 3s 223ms/step
# Accuracy: 0.9940711462450593
# Metric_Precision=0.9949
# Metric_Recall=0.9954
# Metric_f1_score=0.9951
# Metric_Specificity_Macro=0.9988
# G-Mean=0.9953
# Metric AUC=0.9971
# Specificity for each class=   [0.9977 0.9974 1.     1.     0.9975 1.    ] Avg Specificity= 0.9987666666666666
# Accuracy for each class=   [1.     0.9915 1.     0.9904 0.9903 1.    ] Avg Accuracy= 0.9953666666666666
# Classification Report
#               precision    recall  f1-score   support
#
#            0     0.9875    1.0000    0.9937        79
#            1     0.9915    0.9915    0.9915       117
#            2     1.0000    1.0000    1.0000        81
#            3     1.0000    0.9904    0.9952       104
#            4     0.9903    0.9903    0.9903       103
#            5     1.0000    1.0000    1.0000        22
#
#     accuracy                         0.9941       506
#    macro avg     0.9949    0.9954    0.9951       506
# ...

# %% [markdown]
# # Show Image Predict

# %%
from showImagePredict import *
show_imgPredict()
# Out:
# ...
# 16/16 [==============================] - 2s 109ms/step
